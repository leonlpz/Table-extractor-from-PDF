# %%
import camelot as cm

# %%
! dir
# Out:
#  El volumen de la unidad L es DATA
#  El n£mero de serie del volumen es: 365A-79ED
#
#  Directorio de L:\Archivos\Cursos_Diplomados_TI_Coding\FREECODECAMP\Python_Automation
#
# 20/04/2022  19:44    <DIR>          .
# 20/04/2022  19:44    <DIR>          ..
# 18/04/2022  20:56    <DIR>          .ipynb_checkpoints
# 14/04/2022  20:13       160,979,066 2006-sir-ken-robinson-016-fallback-c0fb144f267e9f1a5e2b234fb866c5ec-1200k.mp4
# 12/04/2022  19:29             2,265 hackers_news_scraper.py
# 18/04/2022  20:43           590,268 india_factsheet_economic.pdf
# 12/04/2022  14:58               625 ReadmeHN.txt
# 18/04/2022  20:49             1,962 ReadmeTEPDF.txt
# 12/04/2022  19:40               355 ReadmeTTD.txt
# 20/04/2022  19:44             2,997 Table Extractor from PDF - UN HDI Report.ipynb
# 14/04/2022  20:05             1,179 ted_talk_downloader.py
#                8 archivos    161,578,717 bytes
#                3 dirs  893,468,516,352 bytes libres

# %%
#input_pdf = cm.read_pdf("https://www.undp.org/content/dam/india/docs/india_factsheet_economic_n_hdi.pdf", flavor='lattice', pages='1,2')

# %%
# "stream" -> Worked!, "lattice" ->Did not Work!, #shortcuts: Esc + H

# %%
input_pdf = cm.read_pdf("india_factsheet_economic.pdf", flavor='stream', pages='1,2')

# %%
input_pdf
# Out:
# <TableList n=4>

# %%
for n in input_pdf:
    print(n)
# Out:
# <Table shape=(35, 4)>
# <Table shape=(22, 4)>
# <Table shape=(16, 4)>
# <Table shape=(26, 2)>

# %%
input_pdf[0].df
# Out:
#                                             0  \
# 0   Economic and Human Development Indicators
# 1
# 2
# 3                                           1
# 4                                           2
# 5                                           3
# 6
# 7                                           4
# 8
# 9                                           5
# 10                                          6
# 11                                          7
# 12
# 13                                          8
# 14
# 15                                          9
# 16
# 17                                         10
# 18                                         11
# 19
# 20                                         12
# 21
# 22                                         13
# 23                                         14
# 24                                         15
# 25                                         16
# 26
# 27                                         17
# 28                                         18
# 29
# 30                                         19
# 31
# 32                                         20
# 33                                         21
# 34                                         22
#
#                                                     1        2        3
# 0
# 1                                                         Year     Year
# 2                              Demographic Indicators     2001     2011
# 3                      Total Population (In Billions)    1.028     1.21
# 4                  Sex Ratio (females per 1000 males)      933      940
# 5           Child Sex Ratio  (females per 1000 males)      927      914
# 6                                 Economic Indicators  2005-06     2010
# 7    Gross Domestic Product (Current US $) (millions)   834035  1727111
# 8                                                      2005-06  2009-10
# 9              Contribution of Agriculture to GDP (%)             14.62
# 10                Contribution of Industry to GDP (%)             20.16
# 11                Contribution of Services to GDP (%)             65.22
# 12                                                     2005-06  2009-10
# 13           GNI per capita (current international $)     2280     3550
# 14                                                     2005-06  2009-10
# 15                                GDP Growth Rate (%)      9.5      8.0
# 16                                                     2004-05  2009-10
# 17  Worker Population Ratio Male (usual principal ...     53.6     53.8
# 18  Worker Population Ratio Rate Female (usual pri...     21.5     18.0
# 19                                                        2005     2010
# 20              Inflation, Consumer Prices (annual %)     4.25    11.99
# 21                       Human Development Indicators     2000     2011
# 22                Human Development Index Value (HDI)    0.461    0.547
# 23                              HDI Rank (out of 187)               134
# 24  Inequality Adjusted Human Development Index Value             0.392
# 25                Loss in HDI due to Inequalities (%)              28.7
# 26                                                        2001     2011
# 27                      Gender Inequality Index (GII)   0.5531    0.617
# 28                              GII Rank (out of 146)               129
# 29                                                        1996     2006
# 30                   Gender Empowerment Measure (GEM)    0.416    0.497
# 31                                                        2001     2011
# 32                                  Literacy Rate (%)     64.8    74.04
# 33                             Male Literacy Rate (%)     75.3    82.14
# 34                           Female Literacy Rate (%)     53.7    65.46

# %%
df = input_pdf[0].df.loc[2:5,1:3]

# %%
df
# Out:
#                                            1      2     3
# 2                     Demographic Indicators   2001  2011
# 3             Total Population (In Billions)  1.028  1.21
# 4         Sex Ratio (females per 1000 males)    933   940
# 5  Child Sex Ratio  (females per 1000 males)    927   914

# %%
df = df.reset_index(drop = True)

# %%
df
# Out:
#                                            1      2     3
# 0                     Demographic Indicators   2001  2011
# 1             Total Population (In Billions)  1.028  1.21
# 2         Sex Ratio (females per 1000 males)    933   940
# 3  Child Sex Ratio  (females per 1000 males)    927   914

# %%
df.columns = ["KPI", "2001", "2011"]

# %%
df
# Out:
#                                          KPI   2001  2011
# 0                     Demographic Indicators   2001  2011
# 1             Total Population (In Billions)  1.028  1.21
# 2         Sex Ratio (females per 1000 males)    933   940
# 3  Child Sex Ratio  (females per 1000 males)    927   914

# %%
df.loc[:,["2001", "2011"]] = df.loc[:,["2001", "2011"]].astype(float)

# %%
df
# Out:
#                                          KPI   2001  2011
# 0                     Demographic Indicators   2001  2011
# 1             Total Population (In Billions)  1.028  1.21
# 2         Sex Ratio (females per 1000 males)    933   940
# 3  Child Sex Ratio  (females per 1000 males)    927   914

# %%
df.to_csv("table_from_pdf.csv")

# %%
! dir
# Out:
#  El volumen de la unidad L es DATA
#  El n£mero de serie del volumen es: 365A-79ED
#
#  Directorio de L:\Archivos\Cursos_Diplomados_TI_Coding\FREECODECAMP\Python_Automation
#
# 20/04/2022  20:50    <DIR>          .
# 20/04/2022  20:50    <DIR>          ..
# 18/04/2022  20:56    <DIR>          .ipynb_checkpoints
# 14/04/2022  20:13       160,979,066 2006-sir-ken-robinson-016-fallback-c0fb144f267e9f1a5e2b234fb866c5ec-1200k.mp4
# 12/04/2022  19:29             2,265 hackers_news_scraper.py
# 18/04/2022  20:43           590,268 india_factsheet_economic.pdf
# 12/04/2022  14:58               625 ReadmeHN.txt
# 18/04/2022  20:49             1,962 ReadmeTEPDF.txt
# 12/04/2022  19:40               355 ReadmeTTD.txt
# 20/04/2022  20:50            27,511 Table Extractor from PDF - UN HDI Report.ipynb
# 20/04/2022  20:50               208 table_from_pdf.csv
# 14/04/2022  20:05             1,179 ted_talk_downloader.py
#                9 archivos    161,603,439 bytes
#                3 dirs  893,468,467,200 bytes libres

# %%
df.to_excel("table_from_pdf.xlsx")

# %%
! dir
# Out:
#  El volumen de la unidad L es DATA
#  El n£mero de serie del volumen es: 365A-79ED
#
#  Directorio de L:\Archivos\Cursos_Diplomados_TI_Coding\FREECODECAMP\Python_Automation
#
# 20/04/2022  20:52    <DIR>          .
# 20/04/2022  20:52    <DIR>          ..
# 18/04/2022  20:56    <DIR>          .ipynb_checkpoints
# 14/04/2022  20:13       160,979,066 2006-sir-ken-robinson-016-fallback-c0fb144f267e9f1a5e2b234fb866c5ec-1200k.mp4
# 12/04/2022  19:29             2,265 hackers_news_scraper.py
# 18/04/2022  20:43           590,268 india_factsheet_economic.pdf
# 12/04/2022  14:58               625 ReadmeHN.txt
# 18/04/2022  20:49             1,962 ReadmeTEPDF.txt
# 12/04/2022  19:40               355 ReadmeTTD.txt
# 20/04/2022  20:50            28,798 Table Extractor from PDF - UN HDI Report.ipynb
# 20/04/2022  20:50               208 table_from_pdf.csv
# 20/04/2022  20:52             5,578 table_from_pdf.xlsx
# 14/04/2022  20:05             1,179 ted_talk_downloader.py
#               10 archivos    161,610,304 bytes
#                3 dirs  893,468,454,912 bytes libres

# %%
import pandas as pd

# %%
df2 = pd.read_csv("table_from_pdf.csv")
df2
# Out:
#    Unnamed: 0                                        KPI      2001     2011
# 0           0                     Demographic Indicators  2001.000  2011.00
# 1           1             Total Population (In Billions)     1.028     1.21
# 2           2         Sex Ratio (females per 1000 males)   933.000   940.00
# 3           3  Child Sex Ratio  (females per 1000 males)   927.000   914.00

# %%
import seaborn as sns

# %%
df_melted = df.melt('KPI', var_name='year', value_name='percentage')

# %%
df_melted
# Out:
#                                          KPI  year percentage
# 0                     Demographic Indicators  2001       2001
# 1             Total Population (In Billions)  2001      1.028
# 2         Sex Ratio (females per 1000 males)  2001        933
# 3  Child Sex Ratio  (females per 1000 males)  2001        927
# 4                     Demographic Indicators  2011       2011
# 5             Total Population (In Billions)  2011       1.21
# 6         Sex Ratio (females per 1000 males)  2011        940
# 7  Child Sex Ratio  (females per 1000 males)  2011        914

# %%
sns.barplot(x = "KPI", y = "percentage", hue = "year", data = df_melted)
